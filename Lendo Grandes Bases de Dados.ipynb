# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
import zipfile

# %%
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/microdados_enem2018.zip') as z:
  print(* z.namelist(), sep="\n")
# Out:
# INPUTS/
# INPUTS/INPUT_R_MICRODADOS_ENEM_2018.R
# INPUTS/INPUT_R_ITENS_PROVA_2018.R
# INPUTS/INPUT_SPSS_ITENS_PROVA_2018.sps
# INPUTS/INPUT_SAS_ITENS_PROVA_2018.sas
# INPUTS/INPUT_SPSS_MICRODADOS_ENEM_2018.sps
# INPUTS/INPUT_SAS_MICRODADOS_ENEM_2018.sas
# LEIA-ME e DOCUMENTOS TÉCNICOS/
# LEIA-ME e DOCUMENTOS TÉCNICOS/edital_enem_2018.pdf
# LEIA-ME e DOCUMENTOS TÉCNICOS/matriz_referencia.pdf
# LEIA-ME e DOCUMENTOS TÉCNICOS/manual_de_redacao_do_enem_2018.pdf
# LEIA-ME e DOCUMENTOS TÉCNICOS/Leia_Me_Enem_2018.pdf
# PLANILHAS_TS_ITEM/
# PROVAS E GABARITOS/
# PROVAS E GABARITOS/ENEM_2018_P1_CAD_02_DIA_1_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2018_P1_CAD_03_DIA_1_BRANCO.pdf
# PROVAS E GABARITOS/ENEM_2018_P1_CAD_09_DIA_1_LARANJA_LEDOR.pdf
# PROVAS E GABARITOS/ENEM_2018_P1_CAD_10_DIA_1_VERDE_LIBRAS.pdf
# PROVAS E GABARITOS/ENEM_2018_P1_CAD_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2018_P1_CAD_05_DIA_2_AMARELO.pdf
# PROVAS E GABARITOS/ENEM_2018_P1_CAD_01_DIA_1_AZUL_AMPLIADA.pdf
# ...

# %%
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/microdados_enem2018.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2018.csv') as f:
    df = pd.read_csv(f, sep=";",encoding='ISO-8859-1', nrows=0)

# %%
df
# Out:
# Empty DataFrame
# ...

# %%
df.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
columns = ['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
           'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
           'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA']

# %%
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/microdados_enem2018.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2018.csv') as f:
    df = pd.read_csv(f, sep=";",encoding='ISO-8859-1', usecols=columns)

# %%
df
# Out:
#          NU_INSCRICAO  NU_ANO  ...  TP_ESTADO_CIVIL TP_COR_RACA
# 0        180008202043    2018  ...              1.0           1
# 1        180007197856    2018  ...              0.0           3
# 2        180008517434    2018  ...              0.0           1
# 3        180007661228    2018  ...              0.0           3
# 4        180008787987    2018  ...              0.0           0
# ...               ...     ...  ...              ...         ...
# 5513742  180013945649    2018  ...              1.0           1
# 5513743  180013964149    2018  ...              0.0           3
# 5513744  180013980226    2018  ...              0.0           3
# 5513745  180013934137    2018  ...              0.0           1
# 5513746  180013962906    2018  ...              0.0           3
#
# [5513747 rows x 10 columns]

# %%
df.info

# %%
df_BH = df.query('NO_MUNICIPIO_RESIDENCIA == "Belo Horizonte"')

# %%
df_BH.head()
# Out:
#      NU_INSCRICAO  NU_ANO  ...  TP_ESTADO_CIVIL TP_COR_RACA
# 22   180008196151    2018  ...              0.0           3
# 168  180008309640    2018  ...              0.0           3
# 284  180008309652    2018  ...              0.0           3
# 335  180008895662    2018  ...              1.0           3
# 460  180008788034    2018  ...              0.0           3
#
# [5 rows x 10 columns]

# %%
df_BH.info
# Out:
# <bound method DataFrame.info of          NU_INSCRICAO  NU_ANO  ...  TP_ESTADO_CIVIL TP_COR_RACA
# 22       180008196151    2018  ...              0.0           3
# 168      180008309640    2018  ...              0.0           3
# 284      180008309652    2018  ...              0.0           3
# 335      180008895662    2018  ...              1.0           3
# 460      180008788034    2018  ...              0.0           3
# ...               ...     ...  ...              ...         ...
# 5513306  180013957091    2018  ...              0.0           3
# 5513331  180013923995    2018  ...              0.0           2
# 5513388  180013916606    2018  ...              0.0           1
# 5513547  180013951177    2018  ...              0.0           3
# 5513623  180013945644    2018  ...              1.0           3
#
# [89233 rows x 10 columns]>

# %%
from google.colab import files

# %%
df_BH.to_excel('df_BH.xlsx')
files.download('df_BH.xlsx')
